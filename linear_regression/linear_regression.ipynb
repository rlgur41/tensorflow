# %%
import tensorflow as tf

x_train = [2, 4, 6]
y_train = [2, 4, 6] 

W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name ='bias')

hypothesis = x_train * W + b

# cost(W, b) = 1/m sigma (i = 1 to m) (H(x(i)) - y(i))^2
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.initialize_all_variables())

for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train]) # learnning
    if( step % 20 == 0):
        print(step, cost_val, W_val, b_val)
# Out:
# (0, 0.33948135, array([ 0.66036052], dtype=float32), array([ 1.45331812], dtype=float32), None)
# (20, 0.27404708, array([ 0.70188308], dtype=float32), array([ 1.38102984], dtype=float32), None)
# (40, 0.2456522, array([ 0.71775085], dtype=float32), array([ 1.30752802], dtype=float32), None)
# (60, 0.22019951, array([ 0.73277289], dtype=float32), array([ 1.23793793], dtype=float32), None)
# (80, 0.19738416, array([ 0.74699533], dtype=float32), array([ 1.17205191], dtype=float32), None)
# (100, 0.17693271, array([ 0.76046091], dtype=float32), array([ 1.10967219], dtype=float32), None)
# (120, 0.1586003, array([ 0.77320975], dtype=float32), array([ 1.05061281], dtype=float32), None)
# (140, 0.14216739, array([ 0.78528011], dtype=float32), array([ 0.99469662], dtype=float32), None)
# (160, 0.1274371, array([ 0.79670805], dtype=float32), array([ 0.94175637], dtype=float32), None)
# (180, 0.11423296, array([ 0.80752772], dtype=float32), array([ 0.89163375], dtype=float32), None)
# (200, 0.10239709, array([ 0.81777161], dtype=float32), array([ 0.8441788], dtype=float32), None)
# (220, 0.09178745, array([ 0.82747024], dtype=float32), array([ 0.79924941], dtype=float32), None)
# (240, 0.082277171, array([ 0.83665276], dtype=float32), array([ 0.7567113], dtype=float32), None)
# (260, 0.073752187, array([ 0.84534651], dtype=float32), array([ 0.71643728], dtype=float32), None)
# (280, 0.066110544, array([ 0.85357749], dtype=float32), array([ 0.6783067], dtype=float32), None)
# (300, 0.059260726, array([ 0.8613705], dtype=float32), array([ 0.64220542], dtype=float32), None)
# (320, 0.053120513, array([ 0.86874872], dtype=float32), array([ 0.60802567], dtype=float32), None)
# (340, 0.047616553, array([ 0.87573421], dtype=float32), array([ 0.57566494], dtype=float32), None)
# (360, 0.042682871, array([ 0.882348], dtype=float32), array([ 0.54502666], dtype=float32), None)
# (380, 0.038260449, array([ 0.88860977], dtype=float32), array([ 0.51601893], dtype=float32), None)
# (400, 0.034296185, array([ 0.89453822], dtype=float32), array([ 0.4885551], dtype=float32), None)
# (420, 0.030742703, array([ 0.90015113], dtype=float32), array([ 0.46255302], dtype=float32), None)
# (440, 0.02755733, array([ 0.90546536], dtype=float32), array([ 0.43793476], dtype=float32), None)
# (460, 0.024702063, array([ 0.91049677], dtype=float32), array([ 0.41462669], dtype=float32), None)
# (480, 0.022142619, array([ 0.91526031], dtype=float32), array([ 0.39255926], dtype=float32), None)
# (500, 0.019848356, array([ 0.91977036], dtype=float32), array([ 0.37166625], dtype=float32), None)
# (520, 0.017791839, array([ 0.92404038], dtype=float32), array([ 0.35188529], dtype=float32), None)
# (540, 0.015948405, array([ 0.92808312], dtype=float32), array([ 0.33315703], dtype=float32), None)
# (560, 0.014295942, array([ 0.93191075], dtype=float32), array([ 0.3154256], dtype=float32), None)
# (580, 0.012814713, array([ 0.9355346], dtype=float32), array([ 0.2986379], dtype=float32), None)
# (600, 0.011486948, array([ 0.93896562], dtype=float32), array([ 0.28274363], dtype=float32), None)
# (620, 0.010296735, array([ 0.94221401], dtype=float32), array([ 0.26769534], dtype=float32), None)
# (640, 0.0092298826, array([ 0.94528955], dtype=float32), array([ 0.25344798], dtype=float32), None)
# (660, 0.0082735484, array([ 0.94820142], dtype=float32), array([ 0.23995882], dtype=float32), None)
# (680, 0.0074162912, array([ 0.95095819], dtype=float32), array([ 0.2271876], dtype=float32), None)
# (700, 0.0066478848, array([ 0.9535684], dtype=float32), array([ 0.21509609], dtype=float32), None)
# (720, 0.0059590866, array([ 0.95603955], dtype=float32), array([ 0.20364815], dtype=float32), None)
# (740, 0.0053416663, array([ 0.95837921], dtype=float32), array([ 0.19280952], dtype=float32), None)
# (760, 0.0047881831, array([ 0.96059436], dtype=float32), array([ 0.18254772], dtype=float32), None)
# (780, 0.0042920676, array([ 0.96269166], dtype=float32), array([ 0.17283204], dtype=float32), None)
# (800, 0.0038473625, array([ 0.96467727], dtype=float32), array([ 0.1636335], dtype=float32), None)
# (820, 0.0034487292, array([ 0.96655726], dtype=float32), array([ 0.15492448], dtype=float32), None)
# (840, 0.0030913996, array([ 0.96833718], dtype=float32), array([ 0.146679], dtype=float32), None)
# (860, 0.0027710765, array([ 0.97002232], dtype=float32), array([ 0.13887239], dtype=float32), None)
# (880, 0.0024839777, array([ 0.97161788], dtype=float32), array([ 0.13148127], dtype=float32), None)
# (900, 0.0022265997, array([ 0.97312844], dtype=float32), array([ 0.12448344], dtype=float32), None)
# (920, 0.0019959023, array([ 0.97455859], dtype=float32), array([ 0.11785812], dtype=float32), None)
# (940, 0.0017891, array([ 0.97591269], dtype=float32), array([ 0.11158542], dtype=float32), None)
# (960, 0.0016037241, array([ 0.97719467], dtype=float32), array([ 0.10564657], dtype=float32), None)
# (980, 0.0014375645, array([ 0.9784084], dtype=float32), array([ 0.10002379], dtype=float32), None)
# (1000, 0.0012886083, array([ 0.97955757], dtype=float32), array([ 0.09470026], dtype=float32), None)
# (1020, 0.0011550882, array([ 0.98064554], dtype=float32), array([ 0.08966007], dtype=float32), None)
# (1040, 0.001035417, array([ 0.98167562], dtype=float32), array([ 0.08488813], dtype=float32), None)
# (1060, 0.00092813279, array([ 0.98265088], dtype=float32), array([ 0.08037019], dtype=float32), None)
# (1080, 0.00083196472, array([ 0.98357427], dtype=float32), array([ 0.07609271], dtype=float32), None)
# (1100, 0.00074576377, array([ 0.98444849], dtype=float32), array([ 0.07204287], dtype=float32), None)
# (1120, 0.00066849467, array([ 0.98527622], dtype=float32), array([ 0.06820858], dtype=float32), None)
# (1140, 0.00059922744, array([ 0.98605984], dtype=float32), array([ 0.06457835], dtype=float32), None)
# (1160, 0.00053714035, array([ 0.98680174], dtype=float32), array([ 0.06114135], dtype=float32), None)
# (1180, 0.00048148326, array([ 0.98750418], dtype=float32), array([ 0.05788724], dtype=float32), None)
# (1200, 0.00043159639, array([ 0.98816925], dtype=float32), array([ 0.05480631], dtype=float32), None)
# (1220, 0.00038687768, array([ 0.98879892], dtype=float32), array([ 0.05188937], dtype=float32), None)
# (1240, 0.00034679589, array([ 0.98939508], dtype=float32), array([ 0.04912769], dtype=float32), None)
# (1260, 0.00031086011, array([ 0.98995948], dtype=float32), array([ 0.04651298], dtype=float32), None)
# (1280, 0.00027865372, array([ 0.99049389], dtype=float32), array([ 0.04403744], dtype=float32), None)
# (1300, 0.00024978028, array([ 0.99099982], dtype=float32), array([ 0.04169367], dtype=float32), None)
# (1320, 0.00022389866, array([ 0.99147886], dtype=float32), array([ 0.03947463], dtype=float32), None)
# (1340, 0.00020070188, array([ 0.99193233], dtype=float32), array([ 0.03737371], dtype=float32), None)
# (1360, 0.00017990624, array([ 0.99236172], dtype=float32), array([ 0.0353846], dtype=float32), None)
# (1380, 0.00016126553, array([ 0.99276823], dtype=float32), array([ 0.03350134], dtype=float32), None)
# (1400, 0.00014456015, array([ 0.99315315], dtype=float32), array([ 0.03171833], dtype=float32), None)
# (1420, 0.00012958056, array([ 0.99351752], dtype=float32), array([ 0.03003019], dtype=float32), None)
# (1440, 0.00011615313, array([ 0.99386257], dtype=float32), array([ 0.02843194], dtype=float32), None)
# (1460, 0.00010412001, array([ 0.9941892], dtype=float32), array([ 0.02691874], dtype=float32), None)
# (1480, 9.3331219e-05, array([ 0.99449843], dtype=float32), array([ 0.02548607], dtype=float32), None)
# (1500, 8.3661202e-05, array([ 0.99479127], dtype=float32), array([ 0.02412962], dtype=float32), None)
# (1520, 7.499291e-05, array([ 0.99506849], dtype=float32), array([ 0.02284538], dtype=float32), None)
# (1540, 6.7221299e-05, array([ 0.99533093], dtype=float32), array([ 0.0216295], dtype=float32), None)
# (1560, 6.0255818e-05, array([ 0.99557942], dtype=float32), array([ 0.02047831], dtype=float32), None)
# (1580, 5.4013257e-05, array([ 0.99581474], dtype=float32), array([ 0.01938841], dtype=float32), None)
# (1600, 4.8416699e-05, array([ 0.99603748], dtype=float32), array([ 0.0183565], dtype=float32), None)
# (1620, 4.3402146e-05, array([ 0.99624842], dtype=float32), array([ 0.01737951], dtype=float32), None)
# (1640, 3.8903989e-05, array([ 0.99644804], dtype=float32), array([ 0.01645455], dtype=float32), None)
# (1660, 3.487225e-05, array([ 0.99663705], dtype=float32), array([ 0.01557882], dtype=float32), None)
# (1680, 3.1259595e-05, array([ 0.99681604], dtype=float32), array([ 0.01474968], dtype=float32), None)
# (1700, 2.8021606e-05, array([ 0.99698555], dtype=float32), array([ 0.01396467], dtype=float32), None)
# (1720, 2.5118126e-05, array([ 0.99714601], dtype=float32), array([ 0.01322143], dtype=float32), None)
# (1740, 2.2514692e-05, array([ 0.99729782], dtype=float32), array([ 0.01251774], dtype=float32), None)
# (1760, 2.0181818e-05, array([ 0.99744165], dtype=float32), array([ 0.01185152], dtype=float32), None)
# (1780, 1.8091951e-05, array([ 0.99757779], dtype=float32), array([ 0.01122077], dtype=float32), None)
# (1800, 1.6216682e-05, array([ 0.99770677], dtype=float32), array([ 0.01062357], dtype=float32), None)
# (1820, 1.4535542e-05, array([ 0.99782884], dtype=float32), array([ 0.01005815], dtype=float32), None)
# (1840, 1.3029476e-05, array([ 0.99794436], dtype=float32), array([ 0.00952282], dtype=float32), None)
# (1860, 1.1679217e-05, array([ 0.99805373], dtype=float32), array([ 0.00901598], dtype=float32), None)
# (1880, 1.0469543e-05, array([ 0.99815732], dtype=float32), array([ 0.00853611], dtype=float32), None)
# (1900, 9.3855524e-06, array([ 0.99825543], dtype=float32), array([ 0.00808183], dtype=float32), None)
# (1920, 8.4122612e-06, array([ 0.9983483], dtype=float32), array([ 0.00765168], dtype=float32), None)
# (1940, 7.5413823e-06, array([ 0.99843615], dtype=float32), array([ 0.00724443], dtype=float32), None)
# (1960, 6.7598303e-06, array([ 0.99851942], dtype=float32), array([ 0.00685884], dtype=float32), None)
# (1980, 6.0588304e-06, array([ 0.99859822], dtype=float32), array([ 0.00649379], dtype=float32), None)
# (2000, 5.431682e-06, array([ 0.99867284], dtype=float32), array([ 0.0061482], dtype=float32), None)

# %%
import tensorflow as tf

X = tf.placeholder(dtype=tf.float32, shape =[None])
Y = tf.placeholder(dtype=tf.float32, shape =[None])
W = tf.Variable(tf.random_normal([1]), name ='weight')
b = tf.Variable(tf.random_normal([1]), name ='bias')

hypothesis = W*X + b
cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.initialize_all_variables())

for step in range(2001):
    cost_val, w_val, b_val, _ = sess.run([cost, W, b, train], feed_dict = {X : [1, 2, 3, 4, 5], Y : [1, 2, 3, 4, 5]})
    if step % 20 == 0:
        print("step\tcost_val\tw_val\t\tb_val\n{}\t{}\t{}\t{}".format(step, cost_val, w_val, b_val))
# Out:
# step	cost_val	w_val		b_val
# 0	1.57422590256	[ 0.46960384]	[ 0.93492401]
# step	cost_val	w_val		b_val
# 20	0.16159003973	[ 0.73878759]	[ 0.93863326]
# step	cost_val	w_val		b_val
# 40	0.141093060374	[ 0.75695354]	[ 0.87745476]
# step	cost_val	w_val		b_val
# 60	0.123217605054	[ 0.77287567]	[ 0.81999093]
# step	cost_val	w_val		b_val
# 80	0.107606828213	[ 0.78775018]	[ 0.766289]
# step	cost_val	w_val		b_val
# 100	0.0939738899469	[ 0.80165058]	[ 0.71610427]
# step	cost_val	w_val		b_val
# 120	0.0820681229234	[ 0.8146407]	[ 0.66920608]
# step	cost_val	w_val		b_val
# 140	0.0716707408428	[ 0.82677996]	[ 0.6253792]
# step	cost_val	w_val		b_val
# 160	0.0625905394554	[ 0.83812428]	[ 0.58442259]
# step	cost_val	w_val		b_val
# 180	0.054660834372	[ 0.84872568]	[ 0.54614842]
# step	cost_val	w_val		b_val
# 200	0.0477356798947	[ 0.85863268]	[ 0.51038069]
# step	cost_val	w_val		b_val
# 220	0.0416879467666	[ 0.86789101]	[ 0.47695547]
# step	cost_val	w_val		b_val
# 240	0.0364063903689	[ 0.87654293]	[ 0.44571924]
# step	cost_val	w_val		b_val
# 260	0.0317939855158	[ 0.88462824]	[ 0.41652873]
# step	cost_val	w_val		b_val
# 280	0.0277658998966	[ 0.89218396]	[ 0.38924992]
# step	cost_val	w_val		b_val
# 300	0.0242481920868	[ 0.89924496]	[ 0.36375767]
# step	cost_val	w_val		b_val
# 320	0.0211761146784	[ 0.9058435]	[ 0.33993492]
# step	cost_val	w_val		b_val
# 340	0.0184932611883	[ 0.91200984]	[ 0.31767222]
# step	cost_val	w_val		b_val
# 360	0.0161502845585	[ 0.91777247]	[ 0.29686761]
# step	cost_val	w_val		b_val
# 380	0.0141041725874	[ 0.92315757]	[ 0.27742553]
# step	cost_val	w_val		b_val
# 400	0.0123172840104	[ 0.92819005]	[ 0.25925675]
# step	cost_val	w_val		b_val
# 420	0.0107567859814	[ 0.93289292]	[ 0.24227777]
# step	cost_val	w_val		b_val
# 440	0.00939396861941	[ 0.93728781]	[ 0.22641082]
# step	cost_val	w_val		b_val
# 460	0.00820382870734	[ 0.94139493]	[ 0.211583]
# step	cost_val	w_val		b_val
# 480	0.00716444617137	[ 0.94523305]	[ 0.19772623]
# step	cost_val	w_val		b_val
# 500	0.00625677872449	[ 0.94881982]	[ 0.18477696]
# step	cost_val	w_val		b_val
# 520	0.00546407466754	[ 0.95217162]	[ 0.17267571]
# step	cost_val	w_val		b_val
# 540	0.00477182585746	[ 0.95530397]	[ 0.16136703]
# step	cost_val	w_val		b_val
# 560	0.00416727177799	[ 0.95823109]	[ 0.15079899]
# step	cost_val	w_val		b_val
# 580	0.00363930827007	[ 0.96096659]	[ 0.14092307]
# step	cost_val	w_val		b_val
# 600	0.00317823840305	[ 0.96352285]	[ 0.13169391]
# step	cost_val	w_val		b_val
# 620	0.00277557875961	[ 0.96591181]	[ 0.12306921]
# step	cost_val	w_val		b_val
# 640	0.00242393394001	[ 0.96814424]	[ 0.11500932]
# step	cost_val	w_val		b_val
# 660	0.00211683614179	[ 0.97023052]	[ 0.10747725]
# step	cost_val	w_val		b_val
# 680	0.00184865552001	[ 0.97218013]	[ 0.10043847]
# step	cost_val	w_val		b_val
# 700	0.00161443930119	[ 0.97400212]	[ 0.0938607]
# step	cost_val	w_val		b_val
# 720	0.00140990654472	[ 0.97570473]	[ 0.08771365]
# step	cost_val	w_val		b_val
# 740	0.00123128038831	[ 0.97729588]	[ 0.08196923]
# step	cost_val	w_val		b_val
# 760	0.00107528839726	[ 0.97878277]	[ 0.07660101]
# step	cost_val	w_val		b_val
# 780	0.000939053017646	[ 0.98017222]	[ 0.07158435]
# step	cost_val	w_val		b_val
# 800	0.000820082321297	[ 0.98147082]	[ 0.06689623]
# step	cost_val	w_val		b_val
# 820	0.000716183392797	[ 0.98268431]	[ 0.06251513]
# step	cost_val	w_val		b_val
# 840	0.000625450920779	[ 0.98381829]	[ 0.05842098]
# step	cost_val	w_val		b_val
# 860	0.000546209630556	[ 0.98487806]	[ 0.05459496]
# step	cost_val	w_val		b_val
# 880	0.000477008114103	[ 0.98586839]	[ 0.05101946]
# step	cost_val	w_val		b_val
# 900	0.000416576309362	[ 0.98679394]	[ 0.04767817]
# step	cost_val	w_val		b_val
# 920	0.000363800965715	[ 0.9876588]	[ 0.04455568]
# step	cost_val	w_val		b_val
# 940	0.000317708530929	[ 0.98846704]	[ 0.04163767]
# step	cost_val	w_val		b_val
# 960	0.000277455197647	[ 0.98922235]	[ 0.0389108]
# step	cost_val	w_val		b_val
# 980	0.0002423072292	[ 0.98992813]	[ 0.03636255]
# step	cost_val	w_val		b_val
# 1000	0.000211607199162	[ 0.99058777]	[ 0.03398114]
# step	cost_val	w_val		b_val
# 1020	0.000184800621355	[ 0.9912042]	[ 0.03175569]
# step	cost_val	w_val		b_val
# 1040	0.000161385643878	[ 0.99178022]	[ 0.02967598]
# step	cost_val	w_val		b_val
# 1060	0.00014093882055	[ 0.99231857]	[ 0.02773248]
# step	cost_val	w_val		b_val
# 1080	0.000123081743368	[ 0.99282163]	[ 0.02591626]
# step	cost_val	w_val		b_val
# 1100	0.000107489722723	[ 0.99329174]	[ 0.02421897]
# step	cost_val	w_val		b_val
# 1120	9.38710727496e-05	[ 0.99373102]	[ 0.02263287]
# step	cost_val	w_val		b_val
# 1140	8.19783454062e-05	[ 0.99414158]	[ 0.02115065]
# step	cost_val	w_val		b_val
# 1160	7.15928108548e-05	[ 0.99452525]	[ 0.01976551]
# step	cost_val	w_val		b_val
# 1180	6.25228494755e-05	[ 0.99488378]	[ 0.0184711]
# step	cost_val	w_val		b_val
# 1200	5.46019473404e-05	[ 0.99521887]	[ 0.01726143]
# step	cost_val	w_val		b_val
# 1220	4.76836794405e-05	[ 0.99553198]	[ 0.01613093]
# step	cost_val	w_val		b_val
# 1240	4.16432012571e-05	[ 0.99582464]	[ 0.0150745]
# step	cost_val	w_val		b_val
# 1260	3.63677900168e-05	[ 0.99609804]	[ 0.01408723]
# step	cost_val	w_val		b_val
# 1280	3.17596350214e-05	[ 0.99635363]	[ 0.01316465]
# step	cost_val	w_val		b_val
# 1300	2.77349063253e-05	[ 0.9965924]	[ 0.01230249]
# step	cost_val	w_val		b_val
# 1320	2.4221944841e-05	[ 0.99681556]	[ 0.01149679]
# step	cost_val	w_val		b_val
# 1340	2.11532496905e-05	[ 0.99702412]	[ 0.01074385]
# step	cost_val	w_val		b_val
# 1360	1.8473214368e-05	[ 0.99721903]	[ 0.01004023]
# step	cost_val	w_val		b_val
# 1380	1.61327734531e-05	[ 0.99740112]	[ 0.00938268]
# step	cost_val	w_val		b_val
# 1400	1.40883175845e-05	[ 0.99757135]	[ 0.0087682]
# step	cost_val	w_val		b_val
# 1420	1.23039953905e-05	[ 0.99773037]	[ 0.00819397]
# step	cost_val	w_val		b_val
# 1440	1.07454980025e-05	[ 0.99787903]	[ 0.00765733]
# step	cost_val	w_val		b_val
# 1460	9.38391622185e-06	[ 0.99801797]	[ 0.00715583]
# step	cost_val	w_val		b_val
# 1480	8.19465640234e-06	[ 0.99814773]	[ 0.0066872]
# step	cost_val	w_val		b_val
# 1500	7.15637725079e-06	[ 0.99826908]	[ 0.00624925]
# step	cost_val	w_val		b_val
# 1520	6.24973336016e-06	[ 0.99838239]	[ 0.00583997]
# step	cost_val	w_val		b_val
# 1540	5.45815737496e-06	[ 0.99848837]	[ 0.00545752]
# step	cost_val	w_val		b_val
# 1560	4.76645664094e-06	[ 0.99858737]	[ 0.00510009]
# step	cost_val	w_val		b_val
# 1580	4.16270995629e-06	[ 0.99867988]	[ 0.00476607]
# step	cost_val	w_val		b_val
# 1600	3.63550429938e-06	[ 0.9987663]	[ 0.00445393]
# step	cost_val	w_val		b_val
# 1620	3.17493390867e-06	[ 0.99884713]	[ 0.00416224]
# step	cost_val	w_val		b_val
# 1640	2.77256549452e-06	[ 0.99892259]	[ 0.00388966]
# step	cost_val	w_val		b_val
# 1660	2.42118539973e-06	[ 0.99899316]	[ 0.00363493]
# step	cost_val	w_val		b_val
# 1680	2.11435917663e-06	[ 0.99905908]	[ 0.00339688]
# step	cost_val	w_val		b_val
# 1700	1.84665748293e-06	[ 0.99912071]	[ 0.00317444]
# step	cost_val	w_val		b_val
# 1720	1.61283423949e-06	[ 0.99917829]	[ 0.00296656]
# step	cost_val	w_val		b_val
# 1740	1.40830434248e-06	[ 0.99923211]	[ 0.0027723]
# step	cost_val	w_val		b_val
# 1760	1.23002678265e-06	[ 0.99928236]	[ 0.00259076]
# step	cost_val	w_val		b_val
# 1780	1.07419361939e-06	[ 0.99932939]	[ 0.0024211]
# step	cost_val	w_val		b_val
# 1800	9.38164134823e-07	[ 0.99937332]	[ 0.00226256]
# step	cost_val	w_val		b_val
# 1820	8.19379863515e-07	[ 0.99941432]	[ 0.0021144]
# step	cost_val	w_val		b_val
# 1840	7.15411715646e-07	[ 0.99945271]	[ 0.00197594]
# step	cost_val	w_val		b_val
# 1860	6.24849349151e-07	[ 0.99948847]	[ 0.00184653]
# step	cost_val	w_val		b_val
# 1880	5.4567681218e-07	[ 0.99952197]	[ 0.00172564]
# step	cost_val	w_val		b_val
# 1900	4.765484789e-07	[ 0.99955332]	[ 0.00161264]
# step	cost_val	w_val		b_val
# 1920	4.16228260747e-07	[ 0.99958253]	[ 0.00150706]
# step	cost_val	w_val		b_val
# 1940	3.63423595218e-07	[ 0.99960983]	[ 0.00140839]
# step	cost_val	w_val		b_val
# 1960	3.17406545491e-07	[ 0.9996354]	[ 0.00131621]
# step	cost_val	w_val		b_val
# 1980	2.77263268345e-07	[ 0.9996593]	[ 0.00123004]
# step	cost_val	w_val		b_val
# 2000	2.42160552943e-07	[ 0.99968153]	[ 0.00114952]
