# %%
#using Variable

import tensorflow as tf

x_train = [2, 4, 6]
y_train = [2, 4, 6] 

W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name ='bias')

hypothesis = x_train * W + b

# cost(W, b) = 1/m sigma (i = 1 to m) (H(x(i)) - y(i))^2
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()

sess.run(tf.initialize_all_variables())

for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train]) # learnning
    if( step % 20 == 0):
        print(step, cost_val, W_val, b_val)
# Out:
# (0, 29.62616, array([ 0.09965542], dtype=float32), array([ 0.61900485], dtype=float32))
# (20, 0.077788994, array([ 0.84113389], dtype=float32), array([ 0.73577493], dtype=float32))
# (40, 0.06972909, array([ 0.8496238], dtype=float32), array([ 0.69662255], dtype=float32))
# (60, 0.062504254, array([ 0.85762721], dtype=float32), array([ 0.65954655], dtype=float32))
# (80, 0.056028008, array([ 0.86520463], dtype=float32), array([ 0.62444371], dtype=float32))
# (100, 0.05022281, array([ 0.87237883], dtype=float32), array([ 0.59120905], dtype=float32))
# (120, 0.045019075, array([ 0.87917113], dtype=float32), array([ 0.5597434], dtype=float32))
# (140, 0.040354583, array([ 0.885602], dtype=float32), array([ 0.52995253], dtype=float32))
# (160, 0.036173303, array([ 0.89169049], dtype=float32), array([ 0.50174707], dtype=float32))
# (180, 0.032425333, array([ 0.89745498], dtype=float32), array([ 0.47504285], dtype=float32))
# (200, 0.029065631, array([ 0.90291274], dtype=float32), array([ 0.44975981], dtype=float32))
# (220, 0.026054077, array([ 0.90807992], dtype=float32), array([ 0.42582247], dtype=float32))
# (240, 0.023354566, array([ 0.91297215], dtype=float32), array([ 0.40315911], dtype=float32))
# (260, 0.020934768, array([ 0.91760397], dtype=float32), array([ 0.38170201], dtype=float32))
# (280, 0.018765649, array([ 0.92198932], dtype=float32), array([ 0.3613869], dtype=float32))
# (300, 0.016821289, array([ 0.92614126], dtype=float32), array([ 0.34215292], dtype=float32))
# (320, 0.015078391, array([ 0.93007219], dtype=float32), array([ 0.32394266], dtype=float32))
# (340, 0.013516087, array([ 0.93379396], dtype=float32), array([ 0.30670172], dtype=float32))
# (360, 0.012115657, array([ 0.93731761], dtype=float32), array([ 0.29037824], dtype=float32))
# (380, 0.010860334, array([ 0.94065374], dtype=float32), array([ 0.27492356], dtype=float32))
# (400, 0.0097350739, array([ 0.94381225], dtype=float32), array([ 0.26029146], dtype=float32))
# (420, 0.0087264059, array([ 0.94680274], dtype=float32), array([ 0.24643807], dtype=float32))
# (440, 0.0078222109, array([ 0.94963402], dtype=float32), array([ 0.23332199], dtype=float32))
# (460, 0.0070117544, array([ 0.95231467], dtype=float32), array([ 0.22090399], dtype=float32))
# (480, 0.0062852469, array([ 0.95485258], dtype=float32), array([ 0.2091469], dtype=float32))
# (500, 0.0056340178, array([ 0.95725548], dtype=float32), array([ 0.19801557], dtype=float32))
# (520, 0.0050502517, array([ 0.95953041], dtype=float32), array([ 0.18747666], dtype=float32))
# (540, 0.00452699, array([ 0.96168429], dtype=float32), array([ 0.17749868], dtype=float32))
# (560, 0.0040579285, array([ 0.9637236], dtype=float32), array([ 0.16805178], dtype=float32))
# (580, 0.0036374743, array([ 0.96565425], dtype=float32), array([ 0.1591076], dtype=float32))
# (600, 0.0032605843, array([ 0.96748227], dtype=float32), array([ 0.1506395], dtype=float32))
# (620, 0.0029227494, array([ 0.96921295], dtype=float32), array([ 0.1426221], dtype=float32))
# (640, 0.0026199184, array([ 0.97085148], dtype=float32), array([ 0.13503137], dtype=float32))
# (660, 0.0023484544, array([ 0.97240287], dtype=float32), array([ 0.12784466], dtype=float32))
# (680, 0.0021051457, array([ 0.97387165], dtype=float32), array([ 0.12104046], dtype=float32))
# (700, 0.0018870156, array([ 0.97526228], dtype=float32), array([ 0.11459837], dtype=float32))
# (720, 0.0016915029, array([ 0.97657889], dtype=float32), array([ 0.10849915], dtype=float32))
# (740, 0.0015162291, array([ 0.9778254], dtype=float32), array([ 0.10272455], dtype=float32))
# (760, 0.0013591343, array([ 0.97900558], dtype=float32), array([ 0.09725731], dtype=float32))
# (780, 0.0012183086, array([ 0.98012292], dtype=float32), array([ 0.09208103], dtype=float32))
# (800, 0.0010920785, array([ 0.98118085], dtype=float32), array([ 0.08718026], dtype=float32))
# (820, 0.00097892515, array([ 0.98218244], dtype=float32), array([ 0.08254033], dtype=float32))
# (840, 0.00087750022, array([ 0.98313075], dtype=float32), array([ 0.07814734], dtype=float32))
# (860, 0.0007865876, array([ 0.98402858], dtype=float32), array([ 0.07398814], dtype=float32))
# (880, 0.00070507987, array([ 0.9848786], dtype=float32), array([ 0.07005028], dtype=float32))
# (900, 0.00063202594, array([ 0.98568344], dtype=float32), array([ 0.06632203], dtype=float32))
# (920, 0.00056654197, array([ 0.98644537], dtype=float32), array([ 0.0627922], dtype=float32))
# (940, 0.00050783652, array([ 0.98716676], dtype=float32), array([ 0.05945023], dtype=float32))
# (960, 0.00045522139, array([ 0.98784983], dtype=float32), array([ 0.05628615], dtype=float32))
# (980, 0.00040804993, array([ 0.98849648], dtype=float32), array([ 0.05329046], dtype=float32))
# (1000, 0.00036577767, array([ 0.98910874], dtype=float32), array([ 0.05045421], dtype=float32))
# (1020, 0.00032787808, array([ 0.9896884], dtype=float32), array([ 0.0477689], dtype=float32))
# (1040, 0.00029390396, array([ 0.99023718], dtype=float32), array([ 0.0452265], dtype=float32))
# (1060, 0.00026345276, array([ 0.99075681], dtype=float32), array([ 0.04281944], dtype=float32))
# (1080, 0.00023615656, array([ 0.99124873], dtype=float32), array([ 0.04054053], dtype=float32))
# (1100, 0.00021168595, array([ 0.99171454], dtype=float32), array([ 0.03838288], dtype=float32))
# (1120, 0.00018975708, array([ 0.99215549], dtype=float32), array([ 0.03634005], dtype=float32))
# (1140, 0.00017009395, array([ 0.99257296], dtype=float32), array([ 0.03440592], dtype=float32))
# (1160, 0.0001524676, array([ 0.99296826], dtype=float32), array([ 0.03257474], dtype=float32))
# (1180, 0.00013667204, array([ 0.99334252], dtype=float32), array([ 0.03084104], dtype=float32))
# (1200, 0.00012250881, array([ 0.99369681], dtype=float32), array([ 0.02919962], dtype=float32))
# (1220, 0.00010981548, array([ 0.99403232], dtype=float32), array([ 0.02764554], dtype=float32))
# (1240, 9.8437631e-05, array([ 0.9943499], dtype=float32), array([ 0.02617416], dtype=float32))
# (1260, 8.823994e-05, array([ 0.9946506], dtype=float32), array([ 0.02478113], dtype=float32))
# (1280, 7.9095546e-05, array([ 0.99493533], dtype=float32), array([ 0.02346219], dtype=float32))
# (1300, 7.09011e-05, array([ 0.99520487], dtype=float32), array([ 0.02221347], dtype=float32))
# (1320, 6.3554362e-05, array([ 0.99546009], dtype=float32), array([ 0.02103122], dtype=float32))
# (1340, 5.6968911e-05, array([ 0.99570167], dtype=float32), array([ 0.01991189], dtype=float32))
# (1360, 5.1065905e-05, array([ 0.99593049], dtype=float32), array([ 0.01885213], dtype=float32))
# (1380, 4.5776356e-05, array([ 0.9961471], dtype=float32), array([ 0.01784877], dtype=float32))
# (1400, 4.1033356e-05, array([ 0.9963522], dtype=float32), array([ 0.01689882], dtype=float32))
# (1420, 3.6780337e-05, array([ 0.99654627], dtype=float32), array([ 0.01599941], dtype=float32))
# (1440, 3.2971566e-05, array([ 0.99673015], dtype=float32), array([ 0.01514788], dtype=float32))
# (1460, 2.9554751e-05, array([ 0.99690413], dtype=float32), array([ 0.01434168], dtype=float32))
# (1480, 2.6491509e-05, array([ 0.99706888], dtype=float32), array([ 0.01357835], dtype=float32))
# (1500, 2.374617e-05, array([ 0.99722493], dtype=float32), array([ 0.01285569], dtype=float32))
# (1520, 2.1287116e-05, array([ 0.99737263], dtype=float32), array([ 0.01217148], dtype=float32))
# (1540, 1.9080846e-05, array([ 0.99751246], dtype=float32), array([ 0.01152368], dtype=float32))
# (1560, 1.7104461e-05, array([ 0.99764484], dtype=float32), array([ 0.01091037], dtype=float32))
# (1580, 1.5332416e-05, array([ 0.99777019], dtype=float32), array([ 0.0103297], dtype=float32))
# (1600, 1.3743062e-05, array([ 0.99788886], dtype=float32), array([ 0.00977994], dtype=float32))
# (1620, 1.2319409e-05, array([ 0.99800122], dtype=float32), array([ 0.00925946], dtype=float32))
# (1640, 1.1043366e-05, array([ 0.99810761], dtype=float32), array([ 0.00876662], dtype=float32))
# (1660, 9.8982155e-06, array([ 0.99820828], dtype=float32), array([ 0.00830005], dtype=float32))
# (1680, 8.8733077e-06, array([ 0.99830365], dtype=float32), array([ 0.00785833], dtype=float32))
# (1700, 7.9534029e-06, array([ 0.99839395], dtype=float32), array([ 0.00744008], dtype=float32))
# (1720, 7.1303152e-06, array([ 0.99847943], dtype=float32), array([ 0.00704412], dtype=float32))
# (1740, 6.3906978e-06, array([ 0.99856031], dtype=float32), array([ 0.00666922], dtype=float32))
# (1760, 5.7289021e-06, array([ 0.99863696], dtype=float32), array([ 0.00631427], dtype=float32))
# (1780, 5.1347743e-06, array([ 0.9987095], dtype=float32), array([ 0.00597822], dtype=float32))
# (1800, 4.6030855e-06, array([ 0.99877816], dtype=float32), array([ 0.00566005], dtype=float32))
# (1820, 4.1267308e-06, array([ 0.99884319], dtype=float32), array([ 0.00535883], dtype=float32))
# (1840, 3.6992715e-06, array([ 0.99890476], dtype=float32), array([ 0.00507363], dtype=float32))
# (1860, 3.3152266e-06, array([ 0.998963], dtype=float32), array([ 0.00480364], dtype=float32))
# (1880, 2.9720914e-06, array([ 0.99901825], dtype=float32), array([ 0.00454799], dtype=float32))
# (1900, 2.6639702e-06, array([ 0.99907047], dtype=float32), array([ 0.00430595], dtype=float32))
# (1920, 2.3879065e-06, array([ 0.99911994], dtype=float32), array([ 0.00407679], dtype=float32))
# (1940, 2.1406197e-06, array([ 0.99916679], dtype=float32), array([ 0.00385981], dtype=float32))
# (1960, 1.918992e-06, array([ 0.99921107], dtype=float32), array([ 0.00365438], dtype=float32))
# (1980, 1.7200094e-06, array([ 0.99925315], dtype=float32), array([ 0.00345993], dtype=float32))
# (2000, 1.541736e-06, array([ 0.99929285], dtype=float32), array([ 0.00327578], dtype=float32))
